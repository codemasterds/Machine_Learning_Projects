# %%
pip install kafka-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python\lib\site-packages)
#
# ...

# %%
import pandas as pd
from kafka import KafkaConsumer,KafkaProducer
from time import sleep
from json import dumps
import json

# %%
producer=KafkaProducer(bootstrap_servers=['18.213.76.96:9092'],
                       value_serializer=lambda x: dumps(x).encode('utf-8'))

# %%
producer.send('stock',value="{'hello': 'world'}")

# %%
producer.send('stock',value="{'virat': 'kohil'}")

# %%
producer.send('stock',value="{'virat': 'kohil'}")

# %%
df=pd.read_csv('indexProcessed.csv')
df.head()
# Out:
#   Index        Date         Open         High          Low        Close  \
# 0   HSI  1986-12-31  2568.300049  2568.300049  2568.300049  2568.300049
# 1   HSI  1987-01-02  2540.100098  2540.100098  2540.100098  2540.100098
# 2   HSI  1987-01-05  2552.399902  2552.399902  2552.399902  2552.399902
# 3   HSI  1987-01-06  2583.899902  2583.899902  2583.899902  2583.899902
# 4   HSI  1987-01-07  2607.100098  2607.100098  2607.100098  2607.100098
#
#      Adj Close  Volume    CloseUSD
# 0  2568.300049     0.0  333.879006
# 1  2540.100098     0.0  330.213013
# 2  2552.399902     0.0  331.811987
# 3  2583.899902     0.0  335.906987
# 4  2607.100098     0.0  338.923013

# %%
while True:
    
    producer.send('stock',value=df.sample(1).to_dict(orient="records")[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\python\ml_projects\Machine_Learning_Projects\Stock Market Real-Time Data Analysis Using Kafka\kafka_producer.ipynb Cell 8 in 3
#       <a href='vscode-notebook-cell:/d%3A/python/ml_projects/Machine_Learning_Projects/Stock%20Market%20Real-Time%20Data%20Analysis%20Using%20Kafka/kafka_producer.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> while True:
# ----> <a href='vscode-notebook-cell:/d%3A/python/ml_projects/Machine_Learning_Projects/Stock%20Market%20Real-Time%20Data%20Analysis%20Using%20Kafka/kafka_producer.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     producer.send('stock',value=df.sample(1).to_dict(orient="records")[0])
#
# File c:\python\lib\site-packages\pandas\core\generic.py:4984, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis)
#    4979 if n < 0:
#    4980     raise ValueError(
# ...

# %%
producer.flush()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\python\ml_projects\Machine_Learning_Projects\Stock Market Real-Time Data Analysis Using Kafka\kafka_producer.ipynb Cell 9 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/python/ml_projects/Machine_Learning_Projects/Stock%20Market%20Real-Time%20Data%20Analysis%20Using%20Kafka/kafka_producer.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> producer.flush()
#
# File c:\python\lib\site-packages\kafka\producer\kafka.py:649, in KafkaProducer.flush(self, timeout)
#     647 self._accumulator.begin_flush()
#     648 self._sender.wakeup()
# --> 649 self._accumulator.await_flush_completion(timeout=timeout)
#
# File c:\python\lib\site-packages\kafka\producer\record_accumulator.py:528, in RecordAccumulator.await_flush_completion(self, timeout)
#     525 for batch in self._incomplete.all():
#     526     log.debug('Waiting on produce to %s',
# ...
